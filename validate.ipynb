# %%
import pandas as pd
from sklearn.model_selection import KFold
from sklearn.preprocessing import MinMaxScaler
from sklearn.svm import SVR
import numpy as np

# %%
iris = pd.read_csv('new_scores2.csv') 

# one line split 
train, validation, test = np.split(iris.sample(frac=1), [int(.6*len(iris)),
int(.8*len(iris))])

# %%
set = 5
X_train = train[[train.columns[i] for i in range(train.shape[1]) ]]
X_train.to_csv(f"fold/{set}/train2.csv")
y_train = train[train.columns[-1]]
# Assign the test split
X_test = test[[test.columns[i] for i in range(train.shape[1]) ]]
y_test = test[test.columns[-1]]
X_test.to_csv("fold/test2.csv")
# Assign the validation split
X_val = validation[[validation.columns[i] for i in 
                    range(validation.shape[1]) ]]
y_val = validation[validation.columns[-1]]
X_val.to_csv(f"fold/{set}/val2.csv")

# %%
# Print the sets data shapes
print("X_train shape: {}".format(X_train.shape))
print("X_test shape: {}".format(X_test.shape))
print("y_train shape: {}".format(y_train.shape))
print("y_test shape: {}".format(y_test.shape))
print("X_val shape: {}".format(X_val.shape))
print("y_val shape: {}".format(y_val.shape))
# Out:
# X_train shape: (33, 20)
# X_test shape: (11, 20)
# y_train shape: (33,)
# y_test shape: (11,)
# X_val shape: (11, 20)
# y_val shape: (11,)

# %%
X_train
#set = 1
#X_train.to_csv(f"fold/{set}/train.csv")
#X_test.to_csv("fold/test.csv")
#X_val.to_csv(f"fold/{set}/val.csv")
# Out:
#     Unnamed: 0        number  days  gender    age  afftype    melanch  \
# 17          17  condition_18    13       2  40-44      3.0          2
# 4            4   condition_5    13       2  50-54      2.0          2
# 53          30    control_31    13       1  20-24      NaN        NaN
# 14          14  condition_15    13       2  55-59      2.0          2
# 36          13    control_14    13       1  50-54      NaN        NaN
# 30           7     control_8    13       2  40-44      NaN        NaN
# 28           5     control_6    13       1  25-29      NaN        NaN
# 39          16    control_17     9       1  45-49      NaN        NaN
# 23           0     control_1     8       2  25-29      NaN        NaN
# 21          21  condition_22    14       1  65-69      2.0          2
# 8            8   condition_9    13       2  45-49      1.0  _MISSING_
# 29           6     control_7    13       1  20-24      NaN        NaN
# ...

# %%
X_test
# Out:
#     Unnamed: 0        number  days  gender    age  afftype    melanch  \
# 46          23    control_24    13       2  20-24      NaN        NaN
# 22          22  condition_23    16       1  30-34      2.0          2
# 48          25    control_26    13       1  35-39      NaN        NaN
# 6            6   condition_7    11       1  20-24      1.0  _MISSING_
# 27           4     control_5    13       1  30-34      NaN        NaN
# 50          27    control_28    16       2  45-49      NaN        NaN
# 5            5   condition_6     7       1  35-39      2.0          2
# 54          31    control_32    14       2  25-29      NaN        NaN
# 20          20  condition_21    13       2  35-39      2.0          2
# 38          15    control_16    13       2  40-44      NaN        NaN
# 26           3     control_4    13       1  25-29      NaN        NaN
#
#     inpatient    edu  marriage  work  madrs1  madrs2  DeltaMADRS  \
# ...

# %%
X_val
# Out:
#     Unnamed: 0        number  days  gender    age  afftype    melanch  \
# 7            7   condition_8     5       2  25-29      2.0  _MISSING_
# 51          28    control_29    13       2  50-54      NaN        NaN
# 0            0   condition_1    11       2  35-39      2.0          2
# 45          22    control_23    13       1  20-24      NaN        NaN
# 12          12  condition_13    14       2  35-39      1.0          2
# 19          19  condition_20    13       1  30-34      2.0          1
# 9            9  condition_10     9       2  45-49      2.0          2
# 18          18  condition_19    13       2  50-54      2.0          2
# 13          13  condition_14    14       1  60-64      1.0          2
# 24           1     control_2    20       1  30-34      NaN        NaN
# 1            1   condition_2    18       2  40-44      1.0          2
#
#     inpatient    edu  marriage  work  madrs1  madrs2  DeltaMADRS  \
# ...
