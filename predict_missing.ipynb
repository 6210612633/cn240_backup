# %%
import pandas as pd

# %%
df = pd.read_csv('new_scores2.csv')
df.drop(labels=["DeltaMADRS","Unnamed: 0","number",'afftype','melanch','inpatient',"age","madrs2","marriage","work","depressed","Mean_Q99Act","Std_Q99Act","Stress","days"],axis=1,inplace=True)

#,"Mean_MeanAct","Std_MeanAct","Mean_Q99Act","Std_Q99Act","marriage","gender","age","depressed","madrs1","work","depressed"

# %%
df
# Out:
#     gender  madrs1  Mean_MeanAct  Std_MeanAct  CV_MeanAct  CV_Q99Act
# 0        2    19.0    152.199630    59.218240    0.389083   0.430764
# 1        2    24.0    211.280738    80.924414    0.383018   0.343656
# 2        1    24.0    280.810714    61.577770    0.219286   0.179004
# 3        2    20.0    286.064732   166.280241    0.581268   0.356289
# 4        2    26.0    172.622371    46.444164    0.269051   0.199776
# 5        1    18.0    194.754861    38.794611    0.199197   0.107774
# 6        1    24.0    295.975588   148.639974    0.502203   0.242889
# 7        2    20.0    200.443750    95.169158    0.474792   0.413185
# 8        2    26.0    177.031624    25.805786    0.145769   0.106936
# 9        2    28.0    296.403373    84.898469    0.286429   0.151661
# 10       1    24.0    130.193472    64.907332    0.498545   0.254162
# 11       2    25.0    152.202579    63.119931    0.414710   0.274219
# 12       2    18.0    250.221389    66.762782    0.266815   0.137861
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 55 entries, 0 to 54
# Data columns (total 6 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   gender        55 non-null     int64
#  1   madrs1        23 non-null     float64
#  2   Mean_MeanAct  55 non-null     float64
#  3   Std_MeanAct   55 non-null     float64
#  4   CV_MeanAct    55 non-null     float64
#  5   CV_Q99Act     55 non-null     float64
# dtypes: float64(5), int64(1)
# memory usage: 2.7 KB

# %%
df.shape
# Out:
# (55, 6)

# %%
df.isnull().sum()
# Out:
# gender           0
# madrs1          32
# Mean_MeanAct     0
# Std_MeanAct      0
# CV_MeanAct       0
# CV_Q99Act        0
# dtype: int64

# %%
test_data = df[df["madrs1"].isnull()]

# %%
test_data
# Out:
#     gender  madrs1  Mean_MeanAct  Std_MeanAct  CV_MeanAct  CV_Q99Act
# 23       2     NaN    193.090712    79.180375    0.410068   0.279373
# 24       1     NaN    407.458697   137.730227    0.338023   0.172206
# 25       2     NaN    249.641270    52.558532    0.210536   0.129093
# 26       1     NaN    186.394213    59.268265    0.317973   0.174571
# 27       1     NaN    246.008987   132.278665    0.537699   0.374214
# 28       1     NaN    279.535294   124.969577    0.447062   0.277178
# 29       1     NaN    360.261161   127.277609    0.353293   0.594511
# 30       2     NaN    380.200787   125.202102    0.329305   0.311407
# 31       2     NaN    141.170370    47.241626    0.334643   0.234871
# 32       1     NaN    290.439782    83.298433    0.286801   0.173929
# 33       1     NaN    189.521726    57.936198    0.305697   0.216150
# 34       1     NaN    139.782917    48.599370    0.347677   0.207536
# 35       1     NaN    175.276835    65.257581    0.372311   0.214558
# ...

# %%
df.dropna(inplace=True)

# %%
df
# Out:
#     gender  madrs1  Mean_MeanAct  Std_MeanAct  CV_MeanAct  CV_Q99Act
# 0        2    19.0    152.199630    59.218240    0.389083   0.430764
# 1        2    24.0    211.280738    80.924414    0.383018   0.343656
# 2        1    24.0    280.810714    61.577770    0.219286   0.179004
# 3        2    20.0    286.064732   166.280241    0.581268   0.356289
# 4        2    26.0    172.622371    46.444164    0.269051   0.199776
# 5        1    18.0    194.754861    38.794611    0.199197   0.107774
# 6        1    24.0    295.975588   148.639974    0.502203   0.242889
# 7        2    20.0    200.443750    95.169158    0.474792   0.413185
# 8        2    26.0    177.031624    25.805786    0.145769   0.106936
# 9        2    28.0    296.403373    84.898469    0.286429   0.151661
# 10       1    24.0    130.193472    64.907332    0.498545   0.254162
# 11       2    25.0    152.202579    63.119931    0.414710   0.274219
# 12       2    18.0    250.221389    66.762782    0.266815   0.137861
# ...

# %%
x_train = df.drop("madrs1",axis=1)

# %%
x_train
# Out:
#     gender  Mean_MeanAct  Std_MeanAct  CV_MeanAct  CV_Q99Act
# 0        2    152.199630    59.218240    0.389083   0.430764
# 1        2    211.280738    80.924414    0.383018   0.343656
# 2        1    280.810714    61.577770    0.219286   0.179004
# 3        2    286.064732   166.280241    0.581268   0.356289
# 4        2    172.622371    46.444164    0.269051   0.199776
# 5        1    194.754861    38.794611    0.199197   0.107774
# 6        1    295.975588   148.639974    0.502203   0.242889
# 7        2    200.443750    95.169158    0.474792   0.413185
# 8        2    177.031624    25.805786    0.145769   0.106936
# 9        2    296.403373    84.898469    0.286429   0.151661
# 10       1    130.193472    64.907332    0.498545   0.254162
# 11       2    152.202579    63.119931    0.414710   0.274219
# 12       2    250.221389    66.762782    0.266815   0.137861
# 13       1     73.919345    24.937508    0.337361   0.377598
# ...

# %%
y_train = df["madrs1"]

# %%
y_train
# Out:
# 0     19.0
# 1     24.0
# 2     24.0
# 3     20.0
# 4     26.0
# 5     18.0
# 6     24.0
# 7     20.0
# 8     26.0
# 9     28.0
# 10    24.0
# 11    25.0
# 12    18.0
# 13    28.0
# 14    14.0
# 15    13.0
# 16    17.0
# 17    18.0
# 18    26.0
# 19    27.0
# 20    26.0
# 21    29.0
# 22    29.0
# Name: madrs1, dtype: float64

# %%
from sklearn.linear_model import LinearRegression
from sklearn.ensemble import RandomForestClassifier
#lr = RandomForestClassifier()
lr = LinearRegression()

# %%
lr.fit(x_train, y_train)
# Out:
# LinearRegression()

# %%
x_test = test_data[["Mean_MeanAct","Std_MeanAct","CV_MeanAct","CV_Q99Act"]]

# %%
x_test
# Out:
#     Mean_MeanAct  Std_MeanAct  CV_MeanAct  CV_Q99Act  gender
# 23    193.090712    79.180375    0.410068   0.279373       2
# 24    407.458697   137.730227    0.338023   0.172206       1
# 25    249.641270    52.558532    0.210536   0.129093       2
# 26    186.394213    59.268265    0.317973   0.174571       1
# 27    246.008987   132.278665    0.537699   0.374214       1
# 28    279.535294   124.969577    0.447062   0.277178       1
# 29    360.261161   127.277609    0.353293   0.594511       1
# 30    380.200787   125.202102    0.329305   0.311407       2
# 31    141.170370    47.241626    0.334643   0.234871       2
# 32    290.439782    83.298433    0.286801   0.173929       1
# 33    189.521726    57.936198    0.305697   0.216150       1
# 34    139.782917    48.599370    0.347677   0.207536       1
# 35    175.276835    65.257581    0.372311   0.214558       1
# 36    362.287450   109.543682    0.302367   0.160735       1
# ...

# %%
y_pred = lr.predict(x_test)
# Out:
# C:\Users\james\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\base.py:493: FutureWarning: The feature names should match those that were passed during fit. Starting version 1.2, an error will be raised.
# Feature names must be in the same order as they were in fit.
#
#   warnings.warn(message, FutureWarning)

# %%
y_pred
# Out:
# array([-182.70696399, -369.50554997, -236.45559691, -161.91813926,
#        -217.05133743, -248.93312385, -323.56574492, -358.31251718,
#        -134.14521697, -259.63968729, -164.70007253, -118.01535175,
#        -151.31074058, -327.15352315, -261.08194344, -213.00466043,
#        -214.44551862, -266.78076684, -176.56319849, -289.20734487,
#        -230.37377922, -223.44342318, -171.96763308, -336.63168299,
#        -273.94878875, -282.60504626, -298.67530671, -276.34272399,
#        -252.19761424, -206.85470706, -298.83424718, -149.48742693])

# %%
test_data['y_pred'] = y_pred
# Out:
# C:\Users\james\AppData\Local\Temp\ipykernel_10164\2303368509.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   test_data['y_pred'] = y_pred

# %%
test_data
# Out:
#     gender  madrs1  Mean_MeanAct  Std_MeanAct  CV_MeanAct  CV_Q99Act  \
# 23       2     NaN    193.090712    79.180375    0.410068   0.279373
# 24       1     NaN    407.458697   137.730227    0.338023   0.172206
# 25       2     NaN    249.641270    52.558532    0.210536   0.129093
# 26       1     NaN    186.394213    59.268265    0.317973   0.174571
# 27       1     NaN    246.008987   132.278665    0.537699   0.374214
# 28       1     NaN    279.535294   124.969577    0.447062   0.277178
# 29       1     NaN    360.261161   127.277609    0.353293   0.594511
# 30       2     NaN    380.200787   125.202102    0.329305   0.311407
# 31       2     NaN    141.170370    47.241626    0.334643   0.234871
# 32       1     NaN    290.439782    83.298433    0.286801   0.173929
# 33       1     NaN    189.521726    57.936198    0.305697   0.216150
# 34       1     NaN    139.782917    48.599370    0.347677   0.207536
# 35       1     NaN    175.276835    65.257581    0.372311   0.214558
# ...
